# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
# %matplotlib inline

# %% [markdown]
# # Data analysis of invasive species

# %%
df_2 = pd.read_csv('IASa.csv', delimiter=';',encoding='latin-1')
df_2.head(10)
# Out:
#                  mongodb_id id_easin             scientific_name  \
# 0  574ee5281f2e00013cc1c2b1   R12250         Procambarus clarkii
# 1  574ee5361f2e00013cc1c2b2   R12250         Procambarus clarkii
# 2  57553d9e1f2e00013cc1c2d4   R13698        Sciurus carolinensis
# 3  57554e821f2e00013cc1c2d5   R12250         Procambarus clarkii
# 4  57554e921f2e00013cc1c2d6   R08062          Lagarosiphon major
# 5  57554e971f2e00013cc1c2d7   R13698        Sciurus carolinensis
# 6  57554ea31f2e00013cc1c2d9   R13698        Sciurus carolinensis
# 7  57554ec61f2e00013cc1c2de   R12250         Procambarus clarkii
# 8  57554ece1f2e00013cc1c2df   R12250         Procambarus clarkii
# 9  57554ed31f2e00013cc1c2e0   R15970  Vespa velutina nigrithorax
#
#               common_name      type        family     Status  \
# 0      Red swamp crayfish  Animalia    Arthropoda  Discarded
# 1      Red swamp crayfish  Animalia    Arthropoda  Discarded
# 2  American grey squirrel  Animalia      Mammalia  Discarded
# 3      Red swamp crayfish  Animalia    Arthropoda  Discarded
# 4          African elodea   Plantae  Tracheophyta  Discarded
# 5  American grey squirrel  Animalia      Mammalia  Discarded
# 6  American grey squirrel  Animalia      Mammalia  Discarded
# 7      Red swamp crayfish  Animalia    Arthropoda  Validated
# 8      Red swamp crayfish  Animalia    Arthropoda  Discarded
# 9    Yellow-legged hornet  Animalia    Arthropoda    Unclear
#
#                                    image  image_number  photo
# 0  R12250_574ee5281f2e00013cc1c2b1_0.jpg             0    NaN
# 1  R12250_574ee5361f2e00013cc1c2b2_0.jpg             0    NaN
# 2  R13698_57553d9e1f2e00013cc1c2d4_0.jpg             0    NaN
# 3  R12250_57554e821f2e00013cc1c2d5_0.jpg             0    NaN
# 4  R08062_57554e921f2e00013cc1c2d6_0.jpg             0    NaN
# 5  R13698_57554e971f2e00013cc1c2d7_0.jpg             0    NaN
# 6  R13698_57554ea31f2e00013cc1c2d9_0.jpg             0    NaN
# 7  R12250_57554ec61f2e00013cc1c2de_0.jpg             0    NaN
# 8  R12250_57554ece1f2e00013cc1c2df_0.jpg             0    NaN
# 9  R15970_57554ed31f2e00013cc1c2e0_0.jpg             0    NaN

# %% [markdown]
# ## Number of data and atributes

# %%
df_2.shape
# Out:
# (1192, 10)

# %% [markdown]
# ## List of distinct species and their number

# %%
list = df_2.scientific_name.unique()
list
# Out:
# array(['Procambarus clarkii', 'Sciurus carolinensis',
#        'Lagarosiphon major', 'Vespa velutina nigrithorax',
#        'Trachemys scripta',
#        'Pueraria montana var. lobata = Pueraria lobata',
#        'Cabomba caroliniana', 'Baccharis halimifolia',
#        'Heracleum persicum', 'Hydrocotyle ranunculoides',
#        'Myriophyllum aquaticum', 'Myocastor coypus', 'Orconectes limosus',
#        'Eriocheir sinensis', 'Pseudorasbora parva', 'Perccottus glenii',
#        'Eichhornia crassipes', 'Lysichiton americanus',
#        'Lithobates catesbeianus', 'Orconectes virilis',
#        'Parthenium hysterophorus', 'Persicaria perfoliata',
#        'Procyon lotor', 'Heracleum sosnowskyi',
#        'Pacifastacus leniusculus', 'Alopochen aegyptiacus',
#        'Impatiens glandulifera', 'Alternanthera philoxeroides',
#        'Myriophyllum heterophyllum', 'Corvus splendens', 'Nasua nasua',
#        'Heracleum mantegazzianum', 'Non EASIN species',
#        'Gunnera tinctoria', 'Threskiornis aethiopicus',
#        'Sinanodonta woodiana', 'Dreissena polymorpha', 'Elodea nuttallii',
#        'Asclepias syriaca', 'AmeiurusÊmelas', 'Lepomis gibbosus',
#        'Corbicula fluminea', 'Ludwigia grandiflora',
#        'Ailanthus altissima', 'Acridotheres tristis ', 'Acacia saligna',
#        'Gymnocoronis spilanthoides', 'Cortaderia jubata',
#        'Pennisetum setaceum', 'Herpestes javanicus', 'Carassius gibelio',
#        'Pectinatella magnifica', 'Hypophthalmichthys molitrix ',
#        'Dreissena rostriformis bugensis', 'Ctenopharyngodon idella',
#        'Salvinia molesta', 'Arthurdendyus triangulatus',
#        'Salvelinus fontinalis ', 'Salmo letnica'], dtype=object)

# %% [markdown]
# ## Number of distinct species

# %%
len(df_2.scientific_name.unique())
# Out:
# 59

# %%
ax = df_2['scientific_name'].value_counts().plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for each species")
ax.set_xlabel("Species name")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df_2['scientific_name'].value_counts()
# Out:
# Ailanthus altissima                               563
# Non EASIN species                                  53
# Impatiens glandulifera                             48
# Trachemys scripta                                  47
# Orconectes limosus                                 42
# Pseudorasbora parva                                38
# Corbicula fluminea                                 38
# Sciurus carolinensis                               35
# Lagarosiphon major                                 35
# Sinanodonta woodiana                               29
# Alopochen aegyptiacus                              24
# Myocastor coypus                                   24
# Lysichiton americanus                              23
# Heracleum mantegazzianum                           21
# Vespa velutina nigrithorax                         18
# Procambarus clarkii                                13
# Perccottus glenii                                  12
# Acacia saligna                                     11
# Procyon lotor                                       8
# Heracleum persicum                                  8
# Eichhornia crassipes                                6
# Lepomis gibbosus                                    5
# Dreissena rostriformis bugensis                     4
# Pacifastacus leniusculus                            4
# Baccharis halimifolia                               4
# Alternanthera philoxeroides                         4
# Pueraria montana var. lobata = Pueraria lobata      4
# Eriocheir sinensis                                  4
# Gunnera tinctoria                                   4
# Acridotheres tristis                                4
# Dreissena polymorpha                                4
# Persicaria perfoliata                               3
# Myriophyllum aquaticum                              3
# Heracleum sosnowskyi                                3
# Asclepias syriaca                                   3
# Myriophyllum heterophyllum                          3
# Carassius gibelio                                   3
# Lithobates catesbeianus                             3
# Ludwigia grandiflora                                3
# Pectinatella magnifica                              3
# Corvus splendens                                    2
# Hypophthalmichthys molitrix                         2
# AmeiurusÊmelas                                      2
# Nasua nasua                                         2
# Cortaderia jubata                                   2
# Gymnocoronis spilanthoides                          2
# Pennisetum setaceum                                 2
# Cabomba caroliniana                                 2
# Herpestes javanicus                                 2
# Arthurdendyus triangulatus                          1
# Salmo letnica                                       1
# Ctenopharyngodon idella                             1
# Hydrocotyle ranunculoides                           1
# Threskiornis aethiopicus                            1
# Salvinia molesta                                    1
# Salvelinus fontinalis                               1
# Elodea nuttallii                                    1
# Parthenium hysterophorus                            1
# Orconectes virilis                                  1
# Name: scientific_name, dtype: int64

# %% [markdown]
# # iNaturalist list of species 2017 competition

# %%
df_3=pd.read_csv('iNat-2017.csv')

# %% [markdown]
# ## Which species are found in iNaturalist 2017

# %%
df_n=pd.merge(df_2, df_3,how='inner', on='scientific_name')

# %%
len(df_n['scientific_name'].value_counts())
# Out:
# 18

# %%
ax = df_n['scientific_name'].value_counts().plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for each species")
ax.set_xlabel("Species name")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df_n
# Out:
#                    mongodb_id id_easin      scientific_name  \
# 0    574ee5281f2e00013cc1c2b1   R12250  Procambarus clarkii
# 1    574ee5361f2e00013cc1c2b2   R12250  Procambarus clarkii
# 2    57554e821f2e00013cc1c2d5   R12250  Procambarus clarkii
# 3    57554ec61f2e00013cc1c2de   R12250  Procambarus clarkii
# 4    57554ece1f2e00013cc1c2df   R12250  Procambarus clarkii
# ..                        ...      ...                  ...
# 143  5debe3381d2b6741a2e01f4c   R04013   Corbicula fluminea
# 144  5dc91b3445d0d0f20cec61a9   R19708    Cortaderia jubata
# 145  5dc91b3445d0d0f20cec61a9   R19708    Cortaderia jubata
# 146  5dcd2d7614ca6438c35e7957   R03000  Pennisetum setaceum
# 147  5dcd2d7614ca6438c35e7957   R03000  Pennisetum setaceum
#
#             common_name      type        family     Status  \
# 0    Red swamp crayfish  Animalia    Arthropoda  Discarded
# 1    Red swamp crayfish  Animalia    Arthropoda  Discarded
# 2    Red swamp crayfish  Animalia    Arthropoda  Discarded
# 3    Red swamp crayfish  Animalia    Arthropoda  Validated
# 4    Red swamp crayfish  Animalia    Arthropoda  Discarded
# ..                  ...       ...           ...        ...
# 143     Scoica asiatic_  Animalia    Arthropoda  Validated
# 144         Pampa grass   Plantae  Tracheophyta    Unclear
# 145         Pampa grass   Plantae  Tracheophyta    Unclear
# 146      Fountain grass   Plantae  Tracheophyta  Validated
# 147      Fountain grass   Plantae  Tracheophyta  Validated
#
#                                      image  image_number  photo
# 0    R12250_574ee5281f2e00013cc1c2b1_0.jpg             0    NaN
# 1    R12250_574ee5361f2e00013cc1c2b2_0.jpg             0    NaN
# 2    R12250_57554e821f2e00013cc1c2d5_0.jpg             0    NaN
# 3    R12250_57554ec61f2e00013cc1c2de_0.jpg             0    NaN
# 4    R12250_57554ece1f2e00013cc1c2df_0.jpg             0    NaN
# ..                                     ...           ...    ...
# 143  R04013_5debe3381d2b6741a2e01f4c_0.jpg             0    NaN
# 144  R19708_5dc91b3445d0d0f20cec61a9_0.jpg             0    NaN
# 145  R19708_5dc91b3445d0d0f20cec61a9_1.jpg             1    NaN
# 146  R03000_5dcd2d7614ca6438c35e7957_0.jpg             0    NaN
# 147  R03000_5dcd2d7614ca6438c35e7957_1.jpg             1    NaN
#
# [148 rows x 10 columns]

# %% [markdown]
# ## Select only the validated images

# %%
df_f=df_n.loc[df_n['Status']== 'Validated', ['scientific_name','image']]

# %%
df_f=df_f.drop_duplicates()

# %%
df_f
# Out:
#           scientific_name                                  image
# 3     Procambarus clarkii  R12250_57554ec61f2e00013cc1c2de_0.jpg
# 6     Procambarus clarkii  R12250_57a85ee71f2e00013cc1c34d_0.jpg
# 9     Procambarus clarkii  R12250_5bdc83f8de386109b1dabd1d_0.jpg
# 12    Procambarus clarkii  R12250_5d4fdda0969578791a73d932_0.jpg
# 17   Sciurus carolinensis  R13698_58a46554482da315695c716b_0.jpg
# ..                    ...                                    ...
# 141    Corbicula fluminea  R04013_5debb1691d2b6741a2e01f3f_0.jpg
# 142    Corbicula fluminea  R04013_5debd4301d2b6741a2e01f4a_0.jpg
# 143    Corbicula fluminea  R04013_5debe3381d2b6741a2e01f4c_0.jpg
# 146   Pennisetum setaceum  R03000_5dcd2d7614ca6438c35e7957_0.jpg
# 147   Pennisetum setaceum  R03000_5dcd2d7614ca6438c35e7957_1.jpg
#
# [65 rows x 2 columns]

# %% [markdown]
# # Predict results

# %%
import requests
import argparse
from os import listdir
from os.path import isfile, join

URL = 'http://127.0.0.1:5000/predict'

# %% [markdown]
# ## Send image to server and get results

# %%
def predict_result(image_path):
    # Initialize image path
    mypath='../datasets/'
    image = open(mypath+image_path, 'rb').read()
    payload = {'image': image}
    output_string=''
    r = requests.post(URL, files=payload).json()

    # Ensure the request was successful.
    if r['success']:
        # Loop over the predictions and display them.
        #print(image_path,end ="\t")
        output_string=output_string+image_path +';'
        
        for (i, result) in enumerate(r['predictions']):
            #print(' {}: {:.4f}'.format(result['label'],result['probability']),end ="\t")
            output_string=output_string+'{}'.format(result['label'])+';' +'{:.4f}'.format(result['probability'])+';'
    
        
        #print(output_string)
    # Otherwise, the request failed.
    else:
        print('Request failed')
    
    return output_string

# %% [markdown]
# ## Select only validated images

# %%
output_all=''
for x in df_f['image']:
    print(x)
    string = predict_result(x)
    #string=''
    output_all=output_all+string+ '\n'
    
#print(output_all)

text_file = open("Output-fin.csv", "w")
text_file.write(output_all)
text_file.close()
# Out:
# R12250_57554ec61f2e00013cc1c2de_0.jpg
# R12250_57a85ee71f2e00013cc1c34d_0.jpg
# R12250_5bdc83f8de386109b1dabd1d_0.jpg
# R12250_5d4fdda0969578791a73d932_0.jpg
# R13698_58a46554482da315695c716b_0.jpg
# R13698_5ad30264efac6409c12d4ed6_0.jpg
# R13698_5afb3f50efac6409c12d4f08_0.jpg
# R13698_5dc91aee45d0d0f20cec61a8_0.jpg
# R13698_5e105c7bf33ad825e8d713b3_0.jpg
# R18934_598db5f7dff661b40a8a74fb_0.jpg
# R18934_598dbe22dff661b40a8a74fd_0.jpg
# R05440_5c5b641a945cea09ab19c081_0.jpg
# R05440_5d9de56221dc7b184f5b8093_0.jpg
# R05440_5db5e69a21dc7b184f5b8103_0.jpg
# R05440_5db5e69a21dc7b184f5b8103_1.jpg
# R10676_5b30d223efac6409c12d4f0c_0.jpg
# R10676_5b30d223efac6409c12d4f0c_1.jpg
# R10676_5b30d38aefac6409c12d4f0d_0.jpg
# R01529_5d93378808717f095486f590_0.jpg
# R01529_5d93378808717f095486f590_1.jpg
# R08376_5d59762ee06738509c214a7b_0.jpg
# R08376_5d59762ee06738509c214a7b_1.jpg
# R08376_5d59762ee06738509c214a7b_2.jpg
# R08376_5d597a98e06738509c214a7c_0.jpg
# R08376_5d597a98e06738509c214a7c_1.jpg
# R04013_5d5980afe06738509c214a7d_0.jpg
# R04013_5d5a98e4e06738509c214a80_0.jpg
# R04013_5d5a98e4e06738509c214a80_1.jpg
# R04013_5d5a98e4e06738509c214a80_2.jpg
# R04013_5d5a9b49e06738509c214a81_0.jpg
# R04013_5d5a9b49e06738509c214a81_1.jpg
# R04013_5d5a9e88e06738509c214a83_0.jpg
# R04013_5d5a9e88e06738509c214a83_1.jpg
# R04013_5d6ac534f753e44034c34820_0.jpg
# R04013_5d6ac534f753e44034c34820_1.jpg
# R04013_5d6ac534f753e44034c34820_2.jpg
# R04013_5d6acab4f753e44034c34821_0.jpg
# R04013_5d6acab4f753e44034c34821_1.jpg
# R04013_5d6acab4f753e44034c34821_2.jpg
# R04013_5d6acc3af753e44034c34822_0.jpg
# R04013_5d6acc3af753e44034c34822_1.jpg
# R04013_5d6acc3af753e44034c34822_2.jpg
# R04013_5d6ace53f753e44034c34823_0.jpg
# R04013_5d6ace53f753e44034c34823_1.jpg
# R04013_5d6ace53f753e44034c34823_2.jpg
# R04013_5d6acfc2f753e44034c34824_0.jpg
# R04013_5d6acfc2f753e44034c34824_1.jpg
# R04013_5d6acfc2f753e44034c34824_2.jpg
# R04013_5d6ad0bef753e44034c34825_0.jpg
# R04013_5d6ad0bef753e44034c34825_1.jpg
# R04013_5d6ad0bef753e44034c34825_2.jpg
# R04013_5d6ad1c0f753e44034c34826_0.jpg
# R04013_5d6ad1c0f753e44034c34826_1.jpg
# R04013_5d6ad1c0f753e44034c34826_2.jpg
# R04013_5d6ad2def753e44034c34827_0.jpg
# R04013_5d6ad2def753e44034c34827_1.jpg
# R04013_5d6ad2def753e44034c34827_2.jpg
# R04013_5de92beb1d2b6741a2e01f36_0.jpg
# R04013_5de92beb1d2b6741a2e01f36_1.jpg
# R04013_5debac4b1d2b6741a2e01f3c_0.jpg
# R04013_5debb1691d2b6741a2e01f3f_0.jpg
# R04013_5debd4301d2b6741a2e01f4a_0.jpg
# R04013_5debe3381d2b6741a2e01f4c_0.jpg
# R03000_5dcd2d7614ca6438c35e7957_0.jpg
# R03000_5dcd2d7614ca6438c35e7957_1.jpg

# %%
header_list = ['image', 'P1', 'Q1','P2', 'Q2','P3', 'Q3','P4', 'Q4','P5', 'Q5','P6', 'Q6']
df_predict = pd.read_csv('Output-fin.csv', delimiter=';',names=header_list, index_col=False)
df_predict
# Out:
#                                     image                    P1      Q1  \
# 0   R12250_57554ec61f2e00013cc1c2de_0.jpg   Procambarus clarkii  0.9133
# 1   R12250_57a85ee71f2e00013cc1c34d_0.jpg     Castor canadensis  0.1997
# 2   R12250_5bdc83f8de386109b1dabd1d_0.jpg    Terrapene carolina  0.0975
# 3   R12250_5d4fdda0969578791a73d932_0.jpg   Procambarus clarkii  0.7797
# 4   R13698_58a46554482da315695c716b_0.jpg  Sciurus carolinensis  0.9999
# ..                                    ...                   ...     ...
# 60  R04013_5debb1691d2b6741a2e01f3f_0.jpg    Psilocybe cubensis  0.1413
# 61  R04013_5debd4301d2b6741a2e01f4a_0.jpg    Corbicula fluminea  1.0000
# 62  R04013_5debe3381d2b6741a2e01f4c_0.jpg    Turdus migratorius  0.0963
# 63  R03000_5dcd2d7614ca6438c35e7957_0.jpg    Taxodium distichum  0.7301
# 64  R03000_5dcd2d7614ca6438c35e7957_1.jpg           Carex secta  0.9889
#
#                             P2      Q2                         P3      Q3  \
# 0      Paranephrops planifrons  0.0456            Jasus edwardsii  0.0212
# 1             Myocastor coypus  0.0848          Lontra canadensis  0.0632
# 2          Carduelis carduelis  0.0435        Anaxyrus americanus  0.0339
# 3         Phytolacca americana  0.1768         Romalea microptera  0.0106
# 4               Sciurus alleni  0.0001            Sciurus griseus  0.0000
# ..                         ...     ...                        ...     ...
# 60  Calvia quatuordecimguttata  0.1056  Stropharia rugosoannulata  0.0452
# 61                Dosinia anus  0.0000        Nuttallia obscurata  0.0000
# 62     Lithobates catesbeianus  0.0876       Lithobates clamitans  0.0770
# 63       Dacrydium cupressinum  0.1936        Taxodium mucronatum  0.0407
# 64         Muhlenbergia rigens  0.0048              Nolina texana  0.0024
#
#                            P4      Q4                       P5      Q5  \
# 0          Homarus americanus  0.0050   Grapsus tenuicrustatus  0.0030
# 1             Tamias striatus  0.0512  Sceloporus occidentalis  0.0363
# 2       Lithobates sylvaticus  0.0245         Bombus ternarius  0.0162
# 3             Chrysemys picta  0.0085          Battus philenor  0.0083
# 4         Sciurus arizonensis  0.0000  Tamiasciurus hudsonicus  0.0000
# ..                        ...     ...                      ...     ...
# 60        Abortiporus biennis  0.0451         Phallus hadriani  0.0297
# 61  Calliostoma canaliculatum  0.0000    Betula alleghaniensis  0.0000
# 62             Apis mellifera  0.0449      Anaxyrus americanus  0.0342
# 63       Tillandsia usneoides  0.0133  Casuarina equisetifolia  0.0073
# 64            Cyperus papyrus  0.0016    Austroderia richardii  0.0005
#
#                           P6      Q6
# 0        Potamogeton crispus  0.0012
# 1       Dasypus novemcinctus  0.0319
# 2       Lithobates clamitans  0.0150
# 3           Farancia abacura  0.0074
# 4       Sciurus yucatanensis  0.0000
# ..                       ...     ...
# 60        Erethizon dorsatum  0.0259
# 61         Lampsilis cardium  0.0000
# 62          Sturnus vulgaris  0.0284
# 63  Eucalyptus camaldulensis  0.0038
# 64  Muhlenbergia lindheimeri  0.0004
#
# [65 rows x 13 columns]

# %%
df_f
# Out:
#           scientific_name                                  image
# 3     Procambarus clarkii  R12250_57554ec61f2e00013cc1c2de_0.jpg
# 6     Procambarus clarkii  R12250_57a85ee71f2e00013cc1c34d_0.jpg
# 9     Procambarus clarkii  R12250_5bdc83f8de386109b1dabd1d_0.jpg
# 12    Procambarus clarkii  R12250_5d4fdda0969578791a73d932_0.jpg
# 17   Sciurus carolinensis  R13698_58a46554482da315695c716b_0.jpg
# ..                    ...                                    ...
# 141    Corbicula fluminea  R04013_5debb1691d2b6741a2e01f3f_0.jpg
# 142    Corbicula fluminea  R04013_5debd4301d2b6741a2e01f4a_0.jpg
# 143    Corbicula fluminea  R04013_5debe3381d2b6741a2e01f4c_0.jpg
# 146   Pennisetum setaceum  R03000_5dcd2d7614ca6438c35e7957_0.jpg
# 147   Pennisetum setaceum  R03000_5dcd2d7614ca6438c35e7957_1.jpg
#
# [65 rows x 2 columns]

# %%
df=pd.merge(df_predict, df_f,how='inner', on='image')

# %%
df
# Out:
#                                     image                    P1      Q1  \
# 0   R12250_57554ec61f2e00013cc1c2de_0.jpg   Procambarus clarkii  0.9133
# 1   R12250_57a85ee71f2e00013cc1c34d_0.jpg     Castor canadensis  0.1997
# 2   R12250_5bdc83f8de386109b1dabd1d_0.jpg    Terrapene carolina  0.0975
# 3   R12250_5d4fdda0969578791a73d932_0.jpg   Procambarus clarkii  0.7797
# 4   R13698_58a46554482da315695c716b_0.jpg  Sciurus carolinensis  0.9999
# ..                                    ...                   ...     ...
# 60  R04013_5debb1691d2b6741a2e01f3f_0.jpg    Psilocybe cubensis  0.1413
# 61  R04013_5debd4301d2b6741a2e01f4a_0.jpg    Corbicula fluminea  1.0000
# 62  R04013_5debe3381d2b6741a2e01f4c_0.jpg    Turdus migratorius  0.0963
# 63  R03000_5dcd2d7614ca6438c35e7957_0.jpg    Taxodium distichum  0.7301
# 64  R03000_5dcd2d7614ca6438c35e7957_1.jpg           Carex secta  0.9889
#
#                             P2      Q2                         P3      Q3  \
# 0      Paranephrops planifrons  0.0456            Jasus edwardsii  0.0212
# 1             Myocastor coypus  0.0848          Lontra canadensis  0.0632
# 2          Carduelis carduelis  0.0435        Anaxyrus americanus  0.0339
# 3         Phytolacca americana  0.1768         Romalea microptera  0.0106
# 4               Sciurus alleni  0.0001            Sciurus griseus  0.0000
# ..                         ...     ...                        ...     ...
# 60  Calvia quatuordecimguttata  0.1056  Stropharia rugosoannulata  0.0452
# 61                Dosinia anus  0.0000        Nuttallia obscurata  0.0000
# 62     Lithobates catesbeianus  0.0876       Lithobates clamitans  0.0770
# 63       Dacrydium cupressinum  0.1936        Taxodium mucronatum  0.0407
# 64         Muhlenbergia rigens  0.0048              Nolina texana  0.0024
#
#                            P4      Q4                       P5      Q5  \
# 0          Homarus americanus  0.0050   Grapsus tenuicrustatus  0.0030
# 1             Tamias striatus  0.0512  Sceloporus occidentalis  0.0363
# 2       Lithobates sylvaticus  0.0245         Bombus ternarius  0.0162
# 3             Chrysemys picta  0.0085          Battus philenor  0.0083
# 4         Sciurus arizonensis  0.0000  Tamiasciurus hudsonicus  0.0000
# ..                        ...     ...                      ...     ...
# 60        Abortiporus biennis  0.0451         Phallus hadriani  0.0297
# 61  Calliostoma canaliculatum  0.0000    Betula alleghaniensis  0.0000
# 62             Apis mellifera  0.0449      Anaxyrus americanus  0.0342
# 63       Tillandsia usneoides  0.0133  Casuarina equisetifolia  0.0073
# 64            Cyperus papyrus  0.0016    Austroderia richardii  0.0005
#
#                           P6      Q6       scientific_name
# 0        Potamogeton crispus  0.0012   Procambarus clarkii
# 1       Dasypus novemcinctus  0.0319   Procambarus clarkii
# 2       Lithobates clamitans  0.0150   Procambarus clarkii
# 3           Farancia abacura  0.0074   Procambarus clarkii
# 4       Sciurus yucatanensis  0.0000  Sciurus carolinensis
# ..                       ...     ...                   ...
# 60        Erethizon dorsatum  0.0259    Corbicula fluminea
# 61         Lampsilis cardium  0.0000    Corbicula fluminea
# 62          Sturnus vulgaris  0.0284    Corbicula fluminea
# 63  Eucalyptus camaldulensis  0.0038   Pennisetum setaceum
# 64  Muhlenbergia lindheimeri  0.0004   Pennisetum setaceum
#
# [65 rows x 14 columns]

# %%
df['1_hit'] = df['P1']==df['scientific_name']
df['2_hit'] = df['P2']==df['scientific_name']
df['3_hit'] = df['P3']==df['scientific_name']
df['4_hit'] = df['P4']==df['scientific_name']
df['5_hit'] = df['P5']==df['scientific_name']

# %%
df['Total_5_hit'] = df['1_hit']|df['2_hit']|df['3_hit']|df['4_hit']|df['5_hit']

# %%
df
# Out:
#                                     image                    P1      Q1  \
# 0   R12250_57554ec61f2e00013cc1c2de_0.jpg   Procambarus clarkii  0.9133
# 1   R12250_57a85ee71f2e00013cc1c34d_0.jpg     Castor canadensis  0.1997
# 2   R12250_5bdc83f8de386109b1dabd1d_0.jpg    Terrapene carolina  0.0975
# 3   R12250_5d4fdda0969578791a73d932_0.jpg   Procambarus clarkii  0.7797
# 4   R13698_58a46554482da315695c716b_0.jpg  Sciurus carolinensis  0.9999
# ..                                    ...                   ...     ...
# 60  R04013_5debb1691d2b6741a2e01f3f_0.jpg    Psilocybe cubensis  0.1413
# 61  R04013_5debd4301d2b6741a2e01f4a_0.jpg    Corbicula fluminea  1.0000
# 62  R04013_5debe3381d2b6741a2e01f4c_0.jpg    Turdus migratorius  0.0963
# 63  R03000_5dcd2d7614ca6438c35e7957_0.jpg    Taxodium distichum  0.7301
# 64  R03000_5dcd2d7614ca6438c35e7957_1.jpg           Carex secta  0.9889
#
#                             P2      Q2                         P3      Q3  \
# 0      Paranephrops planifrons  0.0456            Jasus edwardsii  0.0212
# 1             Myocastor coypus  0.0848          Lontra canadensis  0.0632
# 2          Carduelis carduelis  0.0435        Anaxyrus americanus  0.0339
# 3         Phytolacca americana  0.1768         Romalea microptera  0.0106
# 4               Sciurus alleni  0.0001            Sciurus griseus  0.0000
# ..                         ...     ...                        ...     ...
# 60  Calvia quatuordecimguttata  0.1056  Stropharia rugosoannulata  0.0452
# 61                Dosinia anus  0.0000        Nuttallia obscurata  0.0000
# 62     Lithobates catesbeianus  0.0876       Lithobates clamitans  0.0770
# 63       Dacrydium cupressinum  0.1936        Taxodium mucronatum  0.0407
# 64         Muhlenbergia rigens  0.0048              Nolina texana  0.0024
#
#                            P4      Q4                       P5      Q5  \
# 0          Homarus americanus  0.0050   Grapsus tenuicrustatus  0.0030
# 1             Tamias striatus  0.0512  Sceloporus occidentalis  0.0363
# 2       Lithobates sylvaticus  0.0245         Bombus ternarius  0.0162
# 3             Chrysemys picta  0.0085          Battus philenor  0.0083
# 4         Sciurus arizonensis  0.0000  Tamiasciurus hudsonicus  0.0000
# ..                        ...     ...                      ...     ...
# 60        Abortiporus biennis  0.0451         Phallus hadriani  0.0297
# 61  Calliostoma canaliculatum  0.0000    Betula alleghaniensis  0.0000
# 62             Apis mellifera  0.0449      Anaxyrus americanus  0.0342
# 63       Tillandsia usneoides  0.0133  Casuarina equisetifolia  0.0073
# 64            Cyperus papyrus  0.0016    Austroderia richardii  0.0005
#
#                           P6      Q6       scientific_name  1_hit  2_hit  \
# 0        Potamogeton crispus  0.0012   Procambarus clarkii   True  False
# 1       Dasypus novemcinctus  0.0319   Procambarus clarkii  False  False
# 2       Lithobates clamitans  0.0150   Procambarus clarkii  False  False
# 3           Farancia abacura  0.0074   Procambarus clarkii   True  False
# 4       Sciurus yucatanensis  0.0000  Sciurus carolinensis   True  False
# ..                       ...     ...                   ...    ...    ...
# 60        Erethizon dorsatum  0.0259    Corbicula fluminea  False  False
# 61         Lampsilis cardium  0.0000    Corbicula fluminea   True  False
# 62          Sturnus vulgaris  0.0284    Corbicula fluminea  False  False
# 63  Eucalyptus camaldulensis  0.0038   Pennisetum setaceum  False  False
# 64  Muhlenbergia lindheimeri  0.0004   Pennisetum setaceum  False  False
#
#     3_hit  4_hit  5_hit  Total_5_hit
# 0   False  False  False         True
# 1   False  False  False        False
# 2   False  False  False        False
# 3   False  False  False         True
# 4   False  False  False         True
# ..    ...    ...    ...          ...
# 60  False  False  False        False
# 61  False  False  False         True
# 62  False  False  False        False
# 63  False  False  False        False
# 64  False  False  False        False
#
# [65 rows x 20 columns]

# %%
t1=df['1_hit'].value_counts()

# %%
t1
# Out:
# False    42
# True     23
# Name: 1_hit, dtype: int64

# %%
t2=df['Total_5_hit'].value_counts()

# %% [markdown]
# df.loc[df['a'] > 10, ['a','c']]

# %%
t2
# Out:
# False    34
# True     31
# Name: Total_5_hit, dtype: int64

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = '1 hit', '5 hit', 'no hit'
sizes = [t1[1]/len(df.index), 
         t2[1]/len(df.index)-t1[1]/len(df.index),  
         1- t2[1]/len(df.index)]
explode = (0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# # Visualize the results

# %% [markdown]
# ## read the 2017 iNaturalist dataset with images links

# %%
df_iNat2017=pd.read_csv('iNat-cut.csv', delimiter=';')

# %%
df_iNat2017
df_iNat2017.rename(columns={'Category name':'scientific_name',}, 
                 inplace=True)
df_iNat2017
# Out:
#       Competition ID                                scientific_name  \
# 0                  0                           Marmota flaviventris
# 1                  1                           Zonotrichia capensis
# 2                 10                              Nerodia cyclopion
# 3                100  Prosthemadera novaeseelandiae novaeseelandiae
# 4               1000                                 Vanellus miles
# ...              ...                                            ...
# 5084            5084                          Murgantia histrionica
# 5085            5085                           Collomia grandiflora
# 5086            5086                                  Columba livia
# 5087            5087                              Notarctia proxima
# 5088            5088                              Piranga bidentata
#
#      Supercategory                                          Image URL  \
# 0         Mammalia  https://farm1.staticflickr.com/68/185318245_47...
# 1             Aves  https://farm3.staticflickr.com/2248/2195772708...
# 2         Reptilia  https://farm6.staticflickr.com/5225/5691167204...
# 3             Aves  https://static.inaturalist.org/photos/1179556/...
# 4             Aves  https://farm4.staticflickr.com/3252/2313697721...
# ...            ...                                                ...
# 5084       Insecta  http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 5085       Plantae                                                NaN
# 5086          Aves  http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 5087       Insecta                                                NaN
# 5088          Aves  http://api.gbif.org/v1/image?url=http%3A%2F%2F...
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9
# 0           NaN        NaN        NaN        NaN        NaN         NaN
# 1           NaN        NaN        NaN        NaN        NaN         NaN
# 2           NaN        NaN        NaN        NaN        NaN         NaN
# 3           NaN        NaN        NaN        NaN        NaN         NaN
# 4           NaN        NaN        NaN        NaN        NaN         NaN
# ...         ...        ...        ...        ...        ...         ...
# 5084        NaN        NaN        NaN        NaN        NaN         NaN
# 5085        NaN        NaN        NaN        NaN        NaN         NaN
# 5086        NaN        NaN        NaN        NaN        NaN         NaN
# 5087        NaN        NaN        NaN        NaN        NaN         NaN
# 5088        NaN        NaN        NaN        NaN        NaN         NaN
#
# [5089 rows x 10 columns]

# %%
df_i=df_iNat2017[['scientific_name', 'Image URL']]

# %%
df_i
# Out:
#                                     scientific_name  \
# 0                              Marmota flaviventris
# 1                              Zonotrichia capensis
# 2                                 Nerodia cyclopion
# 3     Prosthemadera novaeseelandiae novaeseelandiae
# 4                                    Vanellus miles
# ...                                             ...
# 5084                          Murgantia histrionica
# 5085                           Collomia grandiflora
# 5086                                  Columba livia
# 5087                              Notarctia proxima
# 5088                              Piranga bidentata
#
#                                               Image URL
# 0     https://farm1.staticflickr.com/68/185318245_47...
# 1     https://farm3.staticflickr.com/2248/2195772708...
# 2     https://farm6.staticflickr.com/5225/5691167204...
# 3     https://static.inaturalist.org/photos/1179556/...
# 4     https://farm4.staticflickr.com/3252/2313697721...
# ...                                                 ...
# 5084  http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 5085                                                NaN
# 5086  http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 5087                                                NaN
# 5088  http://api.gbif.org/v1/image?url=http%3A%2F%2F...
#
# [5089 rows x 2 columns]

# %%
df_new=pd.merge(df, df_i, how='left', on='scientific_name')

# %%
df_new
# Out:
#                                     image                    P1      Q1  \
# 0   R12250_57554ec61f2e00013cc1c2de_0.jpg   Procambarus clarkii  0.9133
# 1   R12250_57a85ee71f2e00013cc1c34d_0.jpg     Castor canadensis  0.1997
# 2   R12250_5bdc83f8de386109b1dabd1d_0.jpg    Terrapene carolina  0.0975
# 3   R12250_5d4fdda0969578791a73d932_0.jpg   Procambarus clarkii  0.7797
# 4   R13698_58a46554482da315695c716b_0.jpg  Sciurus carolinensis  0.9999
# ..                                    ...                   ...     ...
# 64  R04013_5debb1691d2b6741a2e01f3f_0.jpg    Psilocybe cubensis  0.1413
# 65  R04013_5debd4301d2b6741a2e01f4a_0.jpg    Corbicula fluminea  1.0000
# 66  R04013_5debe3381d2b6741a2e01f4c_0.jpg    Turdus migratorius  0.0963
# 67  R03000_5dcd2d7614ca6438c35e7957_0.jpg    Taxodium distichum  0.7301
# 68  R03000_5dcd2d7614ca6438c35e7957_1.jpg           Carex secta  0.9889
#
#                             P2      Q2                         P3      Q3  \
# 0      Paranephrops planifrons  0.0456            Jasus edwardsii  0.0212
# 1             Myocastor coypus  0.0848          Lontra canadensis  0.0632
# 2          Carduelis carduelis  0.0435        Anaxyrus americanus  0.0339
# 3         Phytolacca americana  0.1768         Romalea microptera  0.0106
# 4               Sciurus alleni  0.0001            Sciurus griseus  0.0000
# ..                         ...     ...                        ...     ...
# 64  Calvia quatuordecimguttata  0.1056  Stropharia rugosoannulata  0.0452
# 65                Dosinia anus  0.0000        Nuttallia obscurata  0.0000
# 66     Lithobates catesbeianus  0.0876       Lithobates clamitans  0.0770
# 67       Dacrydium cupressinum  0.1936        Taxodium mucronatum  0.0407
# 68         Muhlenbergia rigens  0.0048              Nolina texana  0.0024
#
#                            P4      Q4                       P5  ...  \
# 0          Homarus americanus  0.0050   Grapsus tenuicrustatus  ...
# 1             Tamias striatus  0.0512  Sceloporus occidentalis  ...
# 2       Lithobates sylvaticus  0.0245         Bombus ternarius  ...
# 3             Chrysemys picta  0.0085          Battus philenor  ...
# 4         Sciurus arizonensis  0.0000  Tamiasciurus hudsonicus  ...
# ..                        ...     ...                      ...  ...
# 64        Abortiporus biennis  0.0451         Phallus hadriani  ...
# 65  Calliostoma canaliculatum  0.0000    Betula alleghaniensis  ...
# 66             Apis mellifera  0.0449      Anaxyrus americanus  ...
# 67       Tillandsia usneoides  0.0133  Casuarina equisetifolia  ...
# 68            Cyperus papyrus  0.0016    Austroderia richardii  ...
#
#                           P6      Q6       scientific_name  1_hit  2_hit  \
# 0        Potamogeton crispus  0.0012   Procambarus clarkii   True  False
# 1       Dasypus novemcinctus  0.0319   Procambarus clarkii  False  False
# 2       Lithobates clamitans  0.0150   Procambarus clarkii  False  False
# 3           Farancia abacura  0.0074   Procambarus clarkii   True  False
# 4       Sciurus yucatanensis  0.0000  Sciurus carolinensis   True  False
# ..                       ...     ...                   ...    ...    ...
# 64        Erethizon dorsatum  0.0259    Corbicula fluminea  False  False
# 65         Lampsilis cardium  0.0000    Corbicula fluminea   True  False
# 66          Sturnus vulgaris  0.0284    Corbicula fluminea  False  False
# 67  Eucalyptus camaldulensis  0.0038   Pennisetum setaceum  False  False
# 68  Muhlenbergia lindheimeri  0.0004   Pennisetum setaceum  False  False
#
#     3_hit  4_hit  5_hit  Total_5_hit  \
# 0   False  False  False         True
# 1   False  False  False        False
# 2   False  False  False        False
# 3   False  False  False         True
# 4   False  False  False         True
# ..    ...    ...    ...          ...
# 64  False  False  False        False
# 65  False  False  False         True
# 66  False  False  False        False
# 67  False  False  False        False
# 68  False  False  False        False
#
#                                             Image URL
# 0   http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 1   http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 2   http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 3   http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 4   http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# ..                                                ...
# 64  http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 65  http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 66  http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 67  http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 68  http://api.gbif.org/v1/image?url=http%3A%2F%2F...
#
# [69 rows x 21 columns]

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

image_path='../datasets/'
img = load_img(image_path+df_new['image'][0])
plt.figure(figsize = (5,5))
plt.imshow(img)
plt.axis('off')
plt.title(df_new['scientific_name'][0])
plt.show()

# %%
from PIL import Image
import requests
from io import BytesIO

response = requests.get(df_new['Image URL'][0])
img = Image.open(BytesIO(response.content))
plt.figure(figsize = (5,5))
plt.imshow(img)
plt.axis('off')
plt.title(df_new['scientific_name'][0])
plt.show()

# %%
def retreive_image_online(scientific_name, df_i):
    
    df=df_i.loc[df_i['scientific_name'] == scientific_name, ['scientific_name','Image URL']]
    print (df)
    try:
        response = requests.get(df['Image URL'][0])
        img = Image.open(BytesIO(response.content))
    except:
        print("Something went wrong")
        img = load_img(1.jgp)
    finally:
        print('went')
    return img

# %%
t=retreive_image_online('Marmota flaviventris',df_i)
# Out:
#         scientific_name                                          Image URL
# 0  Marmota flaviventris  https://farm1.staticflickr.com/68/185318245_47...
# went

# %%
t
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375 at 0x7FC8C1910210>

# %%
i=0
img_list=[]
for x in df_new:
    img = load_img(image_path+df_new['image'][i])
    response = requests.get(df_new['Image URL'][i])
    img1 = Image.open(BytesIO(response.content))
    img_list.append(img)
    img_list.append(img1)
    i += 1
    if i > 3:
        break

fig = plt.figure(figsize = (50,50))
plt.title('Validation')

i=0
for x in img_list:
    i += 1
    plt.subplot(6, 2, i)
    plt.imshow(x)
  
    plt.axis('off')
    plt.show()

# %%
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
t = df_new['P1'].tolist()+df_new['P2'].tolist()+df_new['P3'].tolist()+df_new['P4'].tolist()+df_new['P5'].tolist()

# %%
set(t)
# Out:
# {'Abortiporus biennis',
#  'Acacia verticillata',
#  'Acer saccharum',
#  'Acris blanchardi',
#  'Alligator mississippiensis',
#  'Amblema plicata',
#  'Anadenobolus monilicornis',
#  'Anas platyrhynchos',
#  'Anatis labiculata',
#  'Anatis mali',
#  'Anaxyrus americanus',
#  'Anaxyrus boreas',
#  'Aphis nerii',
#  'Apis mellifera',
#  'Apocynum cannabinum',
#  'Aralia nudicaulis',
#  'Asclepias asperula',
#  'Asclepias speciosa',
#  'Asclepias sullivantii',
#  'Asclepias syriaca',
#  'Asplenium trichomanes',
#  'Asterella californica',
#  'Atteva aurea',
#  'Austroderia richardii',
#  'Austrominius modestus',
#  'Austrovenus stutchburyi',
#  'Battus philenor',
#  'Betula alleghaniensis',
#  'Blechnum blechnoides',
#  'Bombus ternarius',
#  'Branta bernicla',
#  'Caesalpinia bonduc',
#  'Calliostoma canaliculatum',
#  'Calvia quatuordecimguttata',
#  'Carduelis carduelis',
#  'Carex secta',
#  'Carnegiea gigantea',
#  'Castor canadensis',
#  'Casuarina equisetifolia',
#  'Chione elevata',
#  'Chromis chromis',
#  'Chromis hypsilepis',
#  'Chrysemys picta',
#  'Coccinella septempunctata',
#  'Cochlicella barbara',
#  'Coenobita compressus',
#  'Coffea arabica',
#  'Conopholis americana',
#  'Corbicula fluminea',
#  'Cordulegaster boltonii',
#  'Cycloneda sanguinea',
#  'Cygnus atratus',
#  'Cymatogaster aggregata',
#  'Cyperus papyrus',
#  'Dacrycarpus dacrydioides',
#  'Dacrydium cupressinum',
#  'Danaus plexippus',
#  'Deconica coprophila',
#  'Dinocardium robustum',
#  'Dipsacus fullonum',
#  'Donax variabilis',
#  'Dosinia anus',
#  'Eichhornia crassipes',
#  'Elgaria multicarinata',
#  'Elliptio complanata',
#  'Ensatina eschscholtzii',
#  'Eontia ponderosa',
#  'Ericameria cuneata',
#  'Eumaeus childrenae',
#  'Euphorbia bicolor',
#  'Formica obscuripes',
#  'Frasera caroliniensis',
#  'Gaultheria antipoda',
#  'Gaultheria depressa',
#  'Grapsus tenuicrustatus',
#  'Griselinia littoralis',
#  'Harmonia axyridis',
#  'Hedera helix',
#  'Helix pomatia',
#  'Hemigrapsus crenulatus',
#  'Hemiphaga novaeseelandiae',
#  'Heracleum maximum',
#  'Herichthys cyanoguttatus',
#  'Heteromeles arbutifolia',
#  'Hippodamia convergens',
#  'Hippodamia parenthesis',
#  'Homarus americanus',
#  'Hormosira banksii',
#  'Hymenophyllum nephrophyllum',
#  'Hypogymnia imshaugii',
#  'Iguana iguana',
#  'Incilius nebulifer',
#  'Jamides celeno',
#  'Jasus edwardsii',
#  'Lampropeltis californiae',
#  'Lampsilis cardium',
#  'Leocarpus fragilis',
#  'Lepomis microlophus',
#  'Lindsaea linearis',
#  'Liriodendron tulipifera',
#  'Lithobates catesbeianus',
#  'Lithobates clamitans',
#  'Lithobates sylvaticus',
#  'Littorina keenae',
#  'Lontra canadensis',
#  'Lottia insessa',
#  'Loxodonta africana',
#  'Lutjanus bohar',
#  'Lynx rufus',
#  'Maclura pomifera',
#  'Macropharyngodon meleagris',
#  'Maoricolpus roseus',
#  'Melanerpes formicivorus',
#  'Melanoides tuberculata',
#  'Meleagris gallopavo',
#  'Menippe mercenaria',
#  'Mentha pulegium',
#  'Mimosa aculeaticarpa',
#  'Monotaxis grandoculis',
#  'Mugil cephalus',
#  'Muhlenbergia rigens',
#  'Myocastor coypus',
#  'Mytilus galloprovincialis',
#  'Narceus annularis',
#  'Nerita melanotragus',
#  'Nerita picea',
#  'Nerodia erythrogaster',
#  'Nerodia fasciata',
#  'Nerodia rhombifer',
#  'Nolina texana',
#  'Novaculichthys taeniourus',
#  'Nuttallia obscurata',
#  'Odocoileus virginianus',
#  'Odontotaenius disjunctus',
#  'Oreochromis aureus',
#  'Ostracion meleagris',
#  'Otala lactea',
#  'Oxyura jamaicensis',
#  'Paranephrops planifrons',
#  'Paryphanta busbyi',
#  'Passer domesticus',
#  'Passer montanus',
#  'Pastinaca sativa',
#  'Pelecanus occidentalis',
#  'Phallus hadriani',
#  'Phoenicurus ochruros',
#  'Phytolacca americana',
#  'Piper excelsum',
#  'Poecile rufescens',
#  'Pogonomyrmex rugosus',
#  'Pollicipes polymerus',
#  'Pomatomus saltatrix',
#  'Porphyrio melanotus',
#  'Priacanthus hamrur',
#  'Procambarus clarkii',
#  'Procyon lotor',
#  'Prunus pensylvanica',
#  'Pseudognaphalium luteoalbum',
#  'Pseudopanax crassifolius',
#  'Psilocybe allenii',
#  'Psilocybe cubensis',
#  'Ptychomnion aciculare',
#  'Pugettia producta',
#  'Romalea microptera',
#  'Ruditapes philippinarum',
#  'Sambucus nigra',
#  'Sceloporus occidentalis',
#  'Sciurus alleni',
#  'Sciurus arizonensis',
#  'Sciurus aureogaster',
#  'Sciurus carolinensis',
#  'Sciurus griseus',
#  'Sciurus niger',
#  'Sciurus yucatanensis',
#  'Scobinichthys granulatus',
#  'Sphenosciadium capitellatum',
#  'Stropharia rugosoannulata',
#  'Tadorna variegata',
#  'Tamias striatus',
#  'Tamiasciurus hudsonicus',
#  'Tanacetum vulgare',
#  'Taxodium distichum',
#  'Taxodium mucronatum',
#  'Terrapene carolina',
#  'Tilia americana',
#  'Tillandsia usneoides',
#  'Toxicodendron radicans',
#  'Turdus migratorius',
#  'Ursus americanus',
#  'Verbascum thapsus',
#  'Xenostrobus neozelanicus',
#  'Yucca brevifolia',
#  'Zachrysia provisoria'}

# %%
df_iNat2017
# Out:
#       Competition ID                                scientific_name  \
# 0                  0                           Marmota flaviventris
# 1                  1                           Zonotrichia capensis
# 2                 10                              Nerodia cyclopion
# 3                100  Prosthemadera novaeseelandiae novaeseelandiae
# 4               1000                                 Vanellus miles
# ...              ...                                            ...
# 5084            5084                          Murgantia histrionica
# 5085            5085                           Collomia grandiflora
# 5086            5086                                  Columba livia
# 5087            5087                              Notarctia proxima
# 5088            5088                              Piranga bidentata
#
#      Supercategory                                          Image URL  \
# 0         Mammalia  https://farm1.staticflickr.com/68/185318245_47...
# 1             Aves  https://farm3.staticflickr.com/2248/2195772708...
# 2         Reptilia  https://farm6.staticflickr.com/5225/5691167204...
# 3             Aves  https://static.inaturalist.org/photos/1179556/...
# 4             Aves  https://farm4.staticflickr.com/3252/2313697721...
# ...            ...                                                ...
# 5084       Insecta  http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 5085       Plantae                                                NaN
# 5086          Aves  http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 5087       Insecta                                                NaN
# 5088          Aves  http://api.gbif.org/v1/image?url=http%3A%2F%2F...
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9
# 0           NaN        NaN        NaN        NaN        NaN         NaN
# 1           NaN        NaN        NaN        NaN        NaN         NaN
# 2           NaN        NaN        NaN        NaN        NaN         NaN
# 3           NaN        NaN        NaN        NaN        NaN         NaN
# 4           NaN        NaN        NaN        NaN        NaN         NaN
# ...         ...        ...        ...        ...        ...         ...
# 5084        NaN        NaN        NaN        NaN        NaN         NaN
# 5085        NaN        NaN        NaN        NaN        NaN         NaN
# 5086        NaN        NaN        NaN        NaN        NaN         NaN
# 5087        NaN        NaN        NaN        NaN        NaN         NaN
# 5088        NaN        NaN        NaN        NaN        NaN         NaN
#
# [5089 rows x 10 columns]

# %%
test1=[]
i=0
for x in df_new:
    test=df_iNat2017.loc[df_new['scientific_name'][i]==df_iNat2017['scientific_name'], ['Image URL']]
    test1.append(test)
    i=i+1

# %%
test1
# Out:
# [                                              Image URL
#  2917  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  2917  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  2917  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  2917  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  3389  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  3389  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  3389  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  3389  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  3389  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  4552  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  4552  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  350   https://farm3.staticflickr.com/2619/4169988685...
#  1312  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  350   https://farm3.staticflickr.com/2619/4169988685...
#  1312  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  350   https://farm3.staticflickr.com/2619/4169988685...
#  1312  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  350   https://farm3.staticflickr.com/2619/4169988685...
#  1312  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  350   https://farm3.staticflickr.com/2619/4169988685...
#  1312  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  350   https://farm3.staticflickr.com/2619/4169988685...
#  1312  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  350   https://farm3.staticflickr.com/2619/4169988685...
#  1312  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  350   https://farm3.staticflickr.com/2619/4169988685...
#  1312  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  4146  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  4146  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  4146  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#       Image URL
#  4762       NaN,
#       Image URL
#  4762       NaN,
#                                                Image URL
#  3363  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  3363  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  3363  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  3363  http://api.gbif.org/v1/image?url=http%3A%2F%2F...,
#                                                Image URL
#  3363  http://api.gbif.org/v1/image?url=http%3A%2F%2F...]

# %%
df_new['Image URL'].head(10)
# Out:
# 0    http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 1    http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 2    http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 3    http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 4    http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 5    http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 6    http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 7    http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 8    http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# 9    http://api.gbif.org/v1/image?url=http%3A%2F%2F...
# Name: Image URL, dtype: object

# %%
df_new['Image URL'].to_csv('file_name.csv')

# %%
from PIL import Image
import requests
from io import BytesIO

response = requests.get(df_new['Image URL'][16])
img = Image.open(BytesIO(response.content))
plt.figure(figsize = (5,5))
plt.imshow(img)
plt.axis('off')
plt.title('Leaf_01')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-400-0004714ac29a> in <module>
#       2
#       3 image_path='../datasets/'
# ----> 4 img = load_img(df_new['Image URL'][0])
#       5 plt.figure(figsize = (5,5))
#       6 plt.imshow(img)
#
# ~/anaconda3/envs/inaturalist/lib/python3.7/site-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     108         raise ImportError('Could not import PIL.Image. '
#     109                           'The use of `load_img` requires PIL.')
# --> 110     img = pil_image.open(path)
#     111     if color_mode == 'grayscale':
#     112         if img.mode != 'L':
#
# ~/anaconda3/envs/inaturalist/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode)
#    2841
#    2842     if filename:
# -> 2843         fp = builtins.open(filename, "rb")
#    2844         exclusive_fp = True
#    2845
#
# FileNotFoundError: [Errno 2] No such file or directory: 'http://api.gbif.org/v1/image?url=http%3A%2F%2Fupload.wikimedia.org%2Fwikipedia%2Fcommons%2F1%2F1a%2FProcambarus_clarkii.jpg&size=s'

# %%
from PIL import Image
import requests
from io import BytesIO


fig = plt.figure(figsize = (10,10))
plt.title('Validation')
i=0
for x in df_new:
    img = load_img(image_path+df_new['image'][i])
    response = requests.get(df_new['Image URL'][i])
    img1 = Image.open(BytesIO(response.content))
    i += 1
    if i > 28:
        break
    
   
    plt.subplot(6, 2, i)
    plt.imshow(img)
    plt.imshow(img1)
    plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-408-bf05bf22c41c> in <module>
#      10     img = load_img(image_path+df_new['image'][i])
#      11     response = requests.get(df_new['Image URL'][i])
# ---> 12     img1 = Image.open(BytesIO(response.content))
#      13     i += 1
#      14     if i > 28:
#
# ~/anaconda3/envs/inaturalist/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode)
#    2894         warnings.warn(message)
#    2895     raise UnidentifiedImageError(
# -> 2896         "cannot identify image file %r" % (filename if filename else fp)
#    2897     )
#    2898
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x7fc8b230c410>

# %%
def gallery(array, ncols=4):
    nindex, height, width, intensity = array.shape
    nrows = nindex//ncols
    assert nindex == nrows*ncols
    # want result.shape = (height*nrows, width*ncols, intensity)
    result = (array.reshape(nrows, ncols, height, width, intensity)
              .swapaxes(1,2)
              .reshape(height*nrows, width*ncols, intensity))
    return result

def make_array():
    from PIL import Image
    return np.array([np.asarray(Image.open('1.jpg').convert('RGB'))]*16)

array = make_array()
result = gallery(array)
plt.imshow(result)
plt.show()
